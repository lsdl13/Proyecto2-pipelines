# %%
import pandas as pd
import numpy as np
import re

# %%
df=pd.read_csv('/Users/luissanchezdeleon/ironhack/w3-pipelines-project/Input/data.csv')

# %%
df.head(5)
# Out:
#    year    western_champion    eastern_champion result        nba_champion  \
# 0  1950  Minneapolis Lakers  Syracuse Nationals    4–2  Minneapolis Lakers
# 1  1951    Rochester Royals     New York Knicks    4–3    Rochester Royals
# 2  1952  Minneapolis Lakers     New York Knicks    4–3  Minneapolis Lakers
# 3  1953  Minneapolis Lakers     New York Knicks    4–1  Minneapolis Lakers
# 4  1954  Minneapolis Lakers  Syracuse Nationals    4–3  Minneapolis Lakers
#
#     nba_vice_champion  final_sweep mvp_name  mvp_height_m  mvp_height_ft  \
# 0  Syracuse Nationals        False      NaN           NaN            NaN
# 1     New York Knicks        False      NaN           NaN            NaN
# 2     New York Knicks        False      NaN           NaN            NaN
# 3     New York Knicks        False      NaN           NaN            NaN
# 4  Syracuse Nationals        False      NaN           NaN            NaN
#
#   mvp_position mvp_team mvp_nationality mvp_status
# ...

# %%
nba=df[['year','western_champion','eastern_champion','result','nba_champion','mvp_name','mvp_height_m','mvp_position','mvp_team','mvp_nationality','mvp_status']]

# %%
nba_eu=nba[nba['year'] < 1957].index

# %%
nba.drop(nba_eu, inplace=True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
nba
# Out:
#     year       western_champion     eastern_champion result  \
# 7   1957        St. Louis Hawks       Boston Celtics    3–4
# 8   1958        St. Louis Hawks       Boston Celtics    4–2
# 9   1959     Minneapolis Lakers       Boston Celtics    0–4
# 10  1960        St. Louis Hawks       Boston Celtics    3–4
# 11  1961        St. Louis Hawks       Boston Celtics    1–4
# ..   ...                    ...                  ...    ...
# 64  2014      San Antonio Spurs           Miami Heat    4–1
# 65  2015  Golden State Warriors  Cleveland Cavaliers    4–2
# 66  2016  Golden State Warriors  Cleveland Cavaliers    4–3
# 67  2017  Golden State Warriors  Cleveland Cavaliers    4-2
# 68  2018  Golden State Warriors  Cleveland Cavaliers    4-0
#
#              nba_champion        mvp_name  mvp_height_m mvp_position  \
# 7          Boston Celtics        B. Cousy          1.85        Guard
# 8         St. Louis Hawks      B. Russell          2.08       Center
# ...
